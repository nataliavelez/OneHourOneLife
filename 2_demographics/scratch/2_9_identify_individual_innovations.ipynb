# %% [markdown]
# # Identify family interactions based on if they shared the same objects

# %%
# %matplotlib inline

import os, re, glob, datetime, json
from os.path import join as opj
import pandas as pd
import numpy as np
import scipy.stats
from tqdm import tqdm
from datetime import datetime

from tqdm.notebook import tqdm
import networkx as nx
import matplotlib.pyplot as plt
import seaborn as sns
from networkx.drawing.nx_agraph import graphviz_layout

# %% [markdown]
# ## load data

# %%
baseDir = '../data/publicMapChangeData/bigserver2.onehouronelife.com/'

# %%
start = 1573982073

# %% [markdown]
# read all mapChange data

# %%
str_extract = lambda pattern, s: re.search(pattern, s).group(0)
int_extract = lambda pattern, s: int(str_extract(pattern, s))

# %%
files_tot = []
for ts in glob.glob(baseDir + '*'):
    files_tot.append(ts)

# %%
file_names = []
for f in files_tot:
    fn = f.split('/')[-1]
    file_names.append(fn)

# %% [markdown]
# sort according to timestamp

# %%
file_names.sort(key=lambda f: int_extract('[0-9]+(?=)', f))

# %%
file_names
# Out:
# ['1573895673time_mapLog.txt',
#  '1573895673time_mapSeed.txt',
#  '1573982073time_mapLog.txt',
#  '1574068473time_mapLog.txt',
#  '1574102503time_mapLog.txt',
#  '1574102503time_mapSeed.txt',
#  '1574151679time_mapLog.txt',
#  '1574238079time_mapLog.txt',
#  '1574324479time_mapLog.txt',
#  '1574410879time_mapLog.txt',
#  '1574497279time_mapLog.txt',
#  '1574552311time_mapLog.txt',
#  '1574638711time_mapLog.txt',
#  '1574725111time_mapLog.txt',
#  '1574749280time_mapLog.txt',
#  '1574835680time_mapLog.txt',
#  '1574848832time_mapLog.txt',
#  '1574935232time_mapLog.txt',
#  '1575021632time_mapLog.txt',
#  '1575108032time_mapLog.txt',
#  '1575194432time_mapLog.txt',
#  '1575280833time_mapLog.txt',
#  '1575367233time_mapLog.txt',
#  '1575453633time_mapLog.txt',
#  '1575540033time_mapLog.txt',
#  '1575626433time_mapLog.txt',
#  '1575693816time_mapLog.txt',
#  '1575780216time_mapLog.txt',
#  '1575866616time_mapLog.txt',
#  '1575953016time_mapLog.txt',
#  '1576038671time_mapLog.txt',
#  '1576038671time_mapSeed.txt',
#  '1576125071time_mapLog.txt',
#  '1576211471time_mapLog.txt',
#  '1576295889time_mapLog.txt',
#  '1576303914time_mapLog.txt',
#  '1576372684time_mapLog.txt',
#  '1576437742time_mapLog.txt',
#  '1576454784time_mapLog.txt',
#  '1576541127time_mapLog.txt',
#  '1576627527time_mapLog.txt',
#  '1576713927time_mapLog.txt',
#  '1576800327time_mapLog.txt',
#  '1576886727time_mapLog.txt',
#  '1576905906time_mapLog.txt',
#  '1576992306time_mapLog.txt',
#  '1577078706time_mapLog.txt',
#  '1577165106time_mapLog.txt',
#  '1577251506time_mapLog.txt',
#  '1577337906time_mapLog.txt',
#  '1577424306time_mapLog.txt',
#  '1577510707time_mapLog.txt',
#  '1577597107time_mapLog.txt',
#  '1577683507time_mapLog.txt',
#  '1577769907time_mapLog.txt',
#  '1577856307time_mapLog.txt',
#  '1577942707time_mapLog.txt',
#  '1578029107time_mapLog.txt',
#  '1578101918time_mapLog.txt',
#  '1578188318time_mapLog.txt',
#  '1578274718time_mapLog.txt',
#  '1578345720time_mapLog.txt',
#  '1578345720time_mapSeed.txt',
#  '1578354747time_mapLog.txt',
#  '1578354747time_mapSeed.txt',
#  '1578441147time_mapLog.txt',
#  '1578527547time_mapLog.txt',
#  '1578610753time_mapLog.txt',
#  '1578697153time_mapLog.txt',
#  '1578783553time_mapLog.txt',
#  '1578869953time_mapLog.txt',
#  '1578956353time_mapLog.txt',
#  '1579042753time_mapLog.txt',
#  '1579129153time_mapLog.txt',
#  '1579215554time_mapLog.txt',
#  '1579301954time_mapLog.txt',
#  '1579302774time_mapLog.txt',
#  '1579389174time_mapLog.txt',
#  '1579475574time_mapLog.txt',
#  '1579561975time_mapLog.txt',
#  '1579648375time_mapLog.txt',
#  '1579713519time_mapSeed.txt',
#  '1579713519time_mapLog.txt',
#  '1579799919time_mapLog.txt',
#  '1579810678time_mapLog.txt',
#  '1579897079time_mapLog.txt',
#  '1579983479time_mapLog.txt',
#  '1580069879time_mapLog.txt',
#  '1580144896time_mapSeed.txt',
#  '1580144896time_mapLog.txt',
#  '1580231296time_mapLog.txt',
#  '1580317696time_mapLog.txt',
#  '1580404097time_mapLog.txt',
#  '1580430735time_mapLog.txt',
#  '1580517135time_mapLog.txt',
#  '1580603535time_mapLog.txt',
#  '1580689935time_mapLog.txt',
#  '1580776335time_mapLog.txt',
#  '1580862735time_mapLog.txt',
#  '1580949135time_mapLog.txt',
#  '1581035536time_mapLog.txt',
#  '1581121936time_mapLog.txt',
#  '1581208336time_mapLog.txt',
#  '1581216046time_mapLog.txt',
#  '1581302446time_mapLog.txt',
#  '1581381390time_mapLog.txt',
#  '1581467790time_mapLog.txt',
#  '1581540490time_mapLog.txt',
#  '1581626890time_mapLog.txt',
#  '1581646322time_mapLog.txt',
#  '1581732722time_mapLog.txt',
#  '1581819123time_mapLog.txt',
#  '1581905523time_mapLog.txt',
#  '1581985139time_mapSeed.txt',
#  '1581985139time_mapLog.txt',
#  '1582071539time_mapLog.txt',
#  '1582157939time_mapLog.txt',
#  '1582244339time_mapLog.txt',
#  '1582330739time_mapLog.txt',
#  '1582417139time_mapLog.txt',
#  '1582503539time_mapLog.txt',
#  '1582589940time_mapLog.txt',
#  '1582676340time_mapLog.txt',
#  '1582762740time_mapLog.txt',
#  '1582849140time_mapLog.txt',
#  '1582935540time_mapLog.txt',
#  '1582946899time_mapLog.txt',
#  '1582959522time_mapLog.txt',
#  '1583045922time_mapLog.txt',
#  '1583132322time_mapLog.txt',
#  '1583218722time_mapLog.txt',
#  '1583305122time_mapLog.txt',
#  '1583391522time_mapLog.txt',
#  '1583461686time_mapLog.txt',
#  '1583548086time_mapLog.txt',
#  '1583634486time_mapLog.txt',
#  '1583642903time_mapSeed.txt',
#  '1583642903time_mapLog.txt',
#  '1583729304time_mapLog.txt',
#  '1583815704time_mapLog.txt',
#  '1583902104time_mapLog.txt',
#  '1583988504time_mapLog.txt',
#  '1584061484time_mapLog.txt',
#  '1584061484time_mapSeed.txt',
#  '1584147884time_mapLog.txt',
#  '1584234284time_mapLog.txt',
#  '1584320684time_mapLog.txt',
#  '1584407084time_mapLog.txt',
#  '1584493484time_mapLog.txt',
#  '1584579885time_mapLog.txt',
#  '1584654920time_mapLog.txt',
#  '1584741320time_mapLog.txt',
#  '1584827720time_mapLog.txt',
#  '1584914120time_mapLog.txt',
#  '1585000520time_mapLog.txt',
#  '1585086920time_mapLog.txt',
#  '1585173320time_mapLog.txt',
#  '1585259720time_mapLog.txt',
#  '1585346120time_mapLog.txt',
#  '1585432521time_mapLog.txt',
#  '1585440511time_mapSeed.txt',
#  '1585440511time_mapLog.txt',
#  '1585512770time_mapLog.txt',
#  '1585512770time_mapSeed.txt',
#  '1585599171time_mapLog.txt',
#  '1585603481time_mapLog.txt',
#  '1585603481time_mapSeed.txt',
#  '1585689882time_mapLog.txt',
#  '1585776282time_mapLog.txt',
#  '1585862682time_mapLog.txt',
#  '1585886551time_mapLog.txt',
#  '1585972951time_mapLog.txt',
#  '1586059351time_mapLog.txt',
#  '1586145751time_mapLog.txt',
#  '1586232151time_mapLog.txt',
#  '1586318551time_mapLog.txt',
#  '1586404951time_mapLog.txt',
#  '1586464055time_mapLog.txt',
#  '1586550455time_mapLog.txt',
#  '1586636855time_mapLog.txt',
#  '1586723255time_mapLog.txt',
#  '1586809655time_mapLog.txt',
#  '1586896056time_mapLog.txt',
#  '1586982456time_mapLog.txt',
#  '1587068856time_mapLog.txt',
#  '1587155256time_mapLog.txt',
#  '1587166656time_mapSeed.txt',
#  '1587166656time_mapLog.txt',
#  '1587253056time_mapLog.txt',
#  '1587339456time_mapLog.txt',
#  '1587425856time_mapLog.txt',
#  '1587512256time_mapLog.txt',
#  '1587598656time_mapLog.txt',
#  '1587684188time_mapLog.txt',
#  '1587770588time_mapLog.txt',
#  '1587856988time_mapLog.txt',
#  '1587943388time_mapLog.txt',
#  '1588029788time_mapLog.txt',
#  '1588032283time_mapLog.txt',
#  '1588118683time_mapLog.txt',
#  '1588205083time_mapLog.txt',
#  '1588291484time_mapLog.txt',
#  '1588374319time_mapLog.txt',
#  '1588460719time_mapLog.txt',
#  '1588547119time_mapLog.txt',
#  '1588633519time_mapLog.txt',
#  '1588719919time_mapLog.txt',
#  '1588806319time_mapLog.txt',
#  '1588892720time_mapLog.txt',
#  '1588907116time_mapLog.txt',
#  '1588918367time_mapLog.txt',
#  '1589004767time_mapLog.txt',
#  '1589091167time_mapLog.txt',
#  '1589177567time_mapLog.txt',
#  '1589263967time_mapLog.txt',
#  '1589350367time_mapLog.txt',
#  '1589436767time_mapLog.txt',
#  '1589523168time_mapLog.txt',
#  '1589583925time_mapLog.txt',
#  '1589670325time_mapLog.txt',
#  '1589756726time_mapLog.txt',
#  '1589843126time_mapLog.txt',
#  '1589929526time_mapLog.txt',
#  '1590015926time_mapLog.txt',
#  '1590102326time_mapLog.txt',
#  '1590188726time_mapLog.txt',
#  '1590204735time_mapLog.txt',
#  '1590291136time_mapLog.txt',
#  '1590377536time_mapLog.txt',
#  '1590463936time_mapLog.txt',
#  '1590550336time_mapLog.txt',
#  '1590636736time_mapLog.txt',
#  '1590723136time_mapLog.txt',
#  '1590809536time_mapLog.txt',
#  '1590875184time_mapLog.txt',
#  '1590961584time_mapLog.txt',
#  '1591047984time_mapLog.txt',
#  '1591134384time_mapLog.txt',
#  '1591220784time_mapLog.txt',
#  '1591307184time_mapLog.txt',
#  '1591393585time_mapLog.txt',
#  '1591479985time_mapLog.txt',
#  '1591566385time_mapLog.txt',
#  '1591652785time_mapLog.txt',
#  '1591739185time_mapLog.txt',
#  '1591825585time_mapLog.txt',
#  '1591911985time_mapLog.txt',
#  '1591998385time_mapLog.txt',
#  '1592084785time_mapLog.txt',
#  '1592171185time_mapLog.txt']

# %% [markdown]
# create a dictionary for mapSeed -- mapLog

# %%
map_seeds = [int_extract('[0-9]+(?=)', fn) for fn in file_names if 'mapSeed' in fn]
map_seeds
# Out:
# [1573895673,
#  1574102503,
#  1576038671,
#  1578345720,
#  1578354747,
#  1579713519,
#  1580144896,
#  1581985139,
#  1583642903,
#  1584061484,
#  1585440511,
#  1585512770,
#  1585603481,
#  1587166656]

# %%
file_dict = {}
for fn in file_names:
    timestamp = int_extract('[0-9]+(?=)', fn)
    if timestamp in map_seeds:
        map_start = timestamp
        file_dict[map_start] = [timestamp]
    else:
        file_dict[map_start].append(timestamp)

# %%
file_dict
# Out:
# {1573895673: [1573895673, 1573982073, 1574068473],
#  1574102503: [1574102503,
#   1574151679,
#   1574238079,
#   1574324479,
#   1574410879,
#   1574497279,
#   1574552311,
#   1574638711,
#   1574725111,
#   1574749280,
#   1574835680,
#   1574848832,
#   1574935232,
#   1575021632,
#   1575108032,
#   1575194432,
#   1575280833,
#   1575367233,
#   1575453633,
#   1575540033,
#   1575626433,
#   1575693816,
#   1575780216,
#   1575866616,
#   1575953016],
#  1576038671: [1576038671,
#   1576125071,
#   1576211471,
#   1576295889,
#   1576303914,
#   1576372684,
#   1576437742,
#   1576454784,
#   1576541127,
#   1576627527,
#   1576713927,
#   1576800327,
#   1576886727,
#   1576905906,
#   1576992306,
#   1577078706,
#   1577165106,
#   1577251506,
#   1577337906,
#   1577424306,
#   1577510707,
#   1577597107,
#   1577683507,
#   1577769907,
#   1577856307,
#   1577942707,
#   1578029107,
#   1578101918,
#   1578188318,
#   1578274718],
#  1578345720: [1578345720],
#  1578354747: [1578354747,
#   1578441147,
#   1578527547,
#   1578610753,
#   1578697153,
#   1578783553,
#   1578869953,
#   1578956353,
#   1579042753,
#   1579129153,
#   1579215554,
#   1579301954,
#   1579302774,
#   1579389174,
#   1579475574,
#   1579561975,
#   1579648375],
#  1579713519: [1579713519,
#   1579799919,
#   1579810678,
#   1579897079,
#   1579983479,
#   1580069879],
#  1580144896: [1580144896,
#   1580231296,
#   1580317696,
#   1580404097,
#   1580430735,
#   1580517135,
#   1580603535,
#   1580689935,
#   1580776335,
#   1580862735,
#   1580949135,
#   1581035536,
#   1581121936,
#   1581208336,
#   1581216046,
#   1581302446,
#   1581381390,
#   1581467790,
#   1581540490,
#   1581626890,
#   1581646322,
#   1581732722,
#   1581819123,
#   1581905523],
#  1581985139: [1581985139,
#   1582071539,
#   1582157939,
#   1582244339,
#   1582330739,
#   1582417139,
#   1582503539,
#   1582589940,
#   1582676340,
#   1582762740,
#   1582849140,
#   1582935540,
#   1582946899,
#   1582959522,
#   1583045922,
#   1583132322,
#   1583218722,
#   1583305122,
#   1583391522,
#   1583461686,
#   1583548086,
#   1583634486],
#  1583642903: [1583642903, 1583729304, 1583815704, 1583902104, 1583988504],
#  1584061484: [1584061484,
#   1584147884,
#   1584234284,
#   1584320684,
#   1584407084,
#   1584493484,
#   1584579885,
#   1584654920,
#   1584741320,
#   1584827720,
#   1584914120,
#   1585000520,
#   1585086920,
#   1585173320,
#   1585259720,
#   1585346120,
#   1585432521],
#  1585440511: [1585440511],
#  1585512770: [1585512770, 1585599171],
#  1585603481: [1585603481,
#   1585689882,
#   1585776282,
#   1585862682,
#   1585886551,
#   1585972951,
#   1586059351,
#   1586145751,
#   1586232151,
#   1586318551,
#   1586404951,
#   1586464055,
#   1586550455,
#   1586636855,
#   1586723255,
#   1586809655,
#   1586896056,
#   1586982456,
#   1587068856,
#   1587155256],
#  1587166656: [1587166656,
#   1587253056,
#   1587339456,
#   1587425856,
#   1587512256,
#   1587598656,
#   1587684188,
#   1587770588,
#   1587856988,
#   1587943388,
#   1588029788,
#   1588032283,
#   1588118683,
#   1588205083,
#   1588291484,
#   1588374319,
#   1588460719,
#   1588547119,
#   1588633519,
#   1588719919,
#   1588806319,
#   1588892720,
#   1588907116,
#   1588918367,
#   1589004767,
#   1589091167,
#   1589177567,
#   1589263967,
#   1589350367,
#   1589436767,
#   1589523168,
#   1589583925,
#   1589670325,
#   1589756726,
#   1589843126,
#   1589929526,
#   1590015926,
#   1590102326,
#   1590188726,
#   1590204735,
#   1590291136,
#   1590377536,
#   1590463936,
#   1590550336,
#   1590636736,
#   1590723136,
#   1590809536,
#   1590875184,
#   1590961584,
#   1591047984,
#   1591134384,
#   1591220784,
#   1591307184,
#   1591393585,
#   1591479985,
#   1591566385,
#   1591652785,
#   1591739185,
#   1591825585,
#   1591911985,
#   1591998385,
#   1592084785,
#   1592171185]}

# %% [markdown]
# ### test: only look at the first slice

# %%
subset = file_dict[list(file_dict.keys())[0]]
subset
# Out:
# [1573895673, 1573982073, 1574068473]

# %%
start = pd.read_csv(baseDir + str(subset[0]) + 'time_mapLog.txt')
time0 = float(start.columns[0].split(": ")[1])
print(time0)
# Out:
# 1573895672.99

# %%
col = ['time','locX','locY','obj','playerID']
data = pd.DataFrame(columns = col)
for i in subset:
    mydf = pd.read_csv(baseDir + str(i) + 'time_mapLog.txt')
    start_time = float(mydf.columns[0].split(": ")[1])
    mydf[['time','locX','locY','obj','playerID']] = mydf[mydf.columns[0]].str.split(" ", expand=True)
    mydf = mydf.dropna()
    mydf['time'] = mydf['time'].astype(float) + start_time - time0
    mydf['playerID'] = mydf['playerID'].astype(int)
    print(len(mydf))
    mydf = mydf[col]
    data = data.append(mydf, ignore_index = True)
# Out:
# 1015275
# 1414424
# 425470

# %%
data.head(n = 10)
# Out:
#      time   locX   locY   obj playerID
# 0   82.36  -5123  -1403    74       -1
# 1   82.36  -5139  -1398  2919       -1
# 2   82.36  -5138  -1398  2917       -1
# 3   82.36  -5137  -1398   198       -1
# 4   82.36  -5136  -1398  2099       -1
# 5   82.36  -5136  -1397  2884       -1
# 6   82.37  -5137  -1383   198       -1
# 7  122.31  -5137  -1395     0  2276905
# 8  125.06  -5138  -1394     0  2276905
# 9  127.21  -5138  -1395     0       -1

# %% [markdown]
# ## Approach 1: focus on location change

# %% [markdown]
# ### load family data and write a find_family function

# %%
fam= pd.read_csv('../2_demographics/outputs/family_playerID.tsv', sep = '\t', index_col = 0)
fam.head(n=10)
# Out:
# /Users/dengwenning/anaconda3/lib/python3.6/site-packages/numpy/lib/arraysetops.py:463: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   mask |= (ar1 == a)
#    playerID                                   family
# 0   3080084  time-1592284232_eve-3080067_name-PICKLE
# 1   3080114  time-1592284232_eve-3080067_name-PICKLE
# 2   3080111  time-1592284232_eve-3080067_name-PICKLE
# 3   3080108  time-1592284232_eve-3080067_name-PICKLE
# 4   3080104  time-1592284232_eve-3080067_name-PICKLE
# 5   3080130  time-1592284232_eve-3080067_name-PICKLE
# 6   3080122  time-1592284232_eve-3080067_name-PICKLE
# 7   3080117  time-1592284232_eve-3080067_name-PICKLE
# 8   3080067  time-1592284232_eve-3080067_name-PICKLE
# 9   3080044    time-1592283401_eve-3080044_name-KORE

# %%
def find_fam(playerId):
    
    family = fam.loc[fam['playerID'] == playerId,'family'].tolist()
    if len(family):    
        fam_name = family[0].split('-')[-1]
    else:
        fam_name = "UnKnown"
    
    return fam_name

# %% [markdown]
# check if every player has a last name (No!) and find the number of players in a family

# %%
fam_dict = {}
for i in data['playerID'].unique():
    if (i != -1) and (i != 0):
        family = fam.query('playerID == @i')['family'].values
        if len(family):
            family_name = family[0].split('-')[-1]
            if family_name in fam_dict.keys():
                fam_dict[family_name] = fam_dict[family_name]+1
            else:
                fam_dict[family_name] = 1

# %% [markdown]
# ### load transition df

# %%
adj_df = pd.read_csv('../3_technology/tech_outputs/adj.csv')
adj_df.head()
# Out:
#    ingredient1  ingredient2  product
# 0          706          707      717
# 1          706          703      718
# 2          100            0       96
# 3         2174         4349     2175
# 4         1323         4348     1328

# %% [markdown]
# ### load object depth data and write a find_depth function

# %%
depth = pd.read_csv('../3_technology/tech_outputs/num_unique_ingredients.csv')
depth.head()
# Out:
#    id                        name  num_ingredients
# 0  11  Skin Tone A &B &C &D &E &F                0
# 1  19                 Female001 D                0
# 2  30        Wild Gooseberry Bush                0
# 3  31                  Gooseberry                1
# 4  32               Big Hard Rock                0

# %%
d = dict([(i,a) for i,a in zip(depth.id, depth.num_ingredients)])
d[0] = 0

# %%
def find_depth(obj):
    try:
        return d[obj]
    except:
        return None

# %% [markdown]
# ### load expertise data (Is expertise correlated with innovation?)

# %%
expertise = pd.read_csv('../data/outputs/player_expertise.tsv', sep = '\t')
expertise = expertise.query('era == "boundless"').reset_index(drop = True)
expertise.head()
# Out:
#          era   timestamp   playerID                                      hash  \
# 0  boundless  1584163133  2783339.0  0002e5ea5ce7cfd761135d255a245a3344af4377
# 1  boundless  1584164596  2783430.0  0002e5ea5ce7cfd761135d255a245a3344af4377
# 2  boundless  1584199272  2784552.0  0002e5ea5ce7cfd761135d255a245a3344af4377
# 3  boundless  1584207170  2784982.0  0002e5ea5ce7cfd761135d255a245a3344af4377
# 4  boundless  1584207184  2784989.0  0002e5ea5ce7cfd761135d255a245a3344af4377
#
#      age  n_life  gametime
# 0  60.00       0     60.00
# 1  23.77       1     83.77
# 2  29.90       2    113.67
# 3   1.43       3    115.10
# 4   0.09       4    115.19

# %%
data = data.iloc[0:10000]

# %%
data['family'] = data['playerID'].apply(find_fam)

# %%
data['objID'] = data['obj'].apply(lambda x: int_extract('[0-9]+',x))

# %%
data.head(n=10)
# Out:
#      time   locX   locY   obj playerID   family  objID
# 0   82.36  -5123  -1403    74       -1  UnKnown     74
# 1   82.36  -5139  -1398  2919       -1  UnKnown   2919
# 2   82.36  -5138  -1398  2917       -1  UnKnown   2917
# 3   82.36  -5137  -1398   198       -1  UnKnown    198
# 4   82.36  -5136  -1398  2099       -1  UnKnown   2099
# 5   82.36  -5136  -1397  2884       -1  UnKnown   2884
# 6   82.37  -5137  -1383   198       -1  UnKnown    198
# 7  122.31  -5137  -1395     0  2276905  ZABICKI      0
# 8  125.06  -5138  -1394     0  2276905  ZABICKI      0
# 9  127.21  -5138  -1395     0       -1  UnKnown      0

# %%
fam_subset = data.query('family == "ZABICKI"')
fam_innovs = fam_subset.groupby(['objID'])['playerID'].apply(lambda x: x.tolist()[0]).to_frame().reset_index()
fam_innovs['depth'] = fam_innovs['objID'].apply(find_depth)
fam_innovs.head()
# Out:
#    objID  playerID  depth
# 0      0   2276905    0.0
# 1     30   2276906    0.0
# 2     31   2276914    1.0
# 3     33   2276930    0.0
# 4     34   2276909    2.0

# %%
len(fam_innovs)
# Out:
# 309

# %%
fam_innovs = fam_innovs.loc[fam_innovs.depth > 0]
fam_innovs = pd.merge(fam_innovs, parsed, on = ['objID','playerID'], how = 'inner')
fam_innovs = fam_innovs.sort_values(by = 'depth', ascending = False).reset_index(drop = True)
fam_innovs.head()
# Out:
#    objID playerID  depth     time   locX   locY  prev_objID prev_playerID
# 0   2669  2276914  378.0   556.16  -5120  -1402      2665.0       2276914
# 1   2669  2276914  378.0   554.15  -5120  -1402      2665.0       2276914
# 2   2665  2276914  376.0   555.31  -5120  -1402      2669.0       2276914
# 3   2665  2276914  376.0   552.93  -5120  -1402         NaN           NaN
# 4   2390  2276909  334.0  1800.32  -5120  -1400         NaN           NaN

# %%
len(fam_innovs)
# Out:
# 1003

# %%
fam = 'ZABICKI'
innovs_to_be_removed = pd.DataFrame(columns = ['fam', 'objID'])
for i,j in fam_innovs.iterrows():
    objID = j['objID']
    playerID = j['playerID']
    time = j['time']
    obj_data = parsed.query('(playerID == @playerID) and (time < @time)')
    prev = obj_data['prev_objID'].values
    if objID in prev:
#         print(objID)
        innovs_to_be_removed = innovs_to_be_removed.append({'fam':fam, 'objID':objID}, ignore_index = True)

# %%
obj_data
# Out:
#        time   locX   locY  objID playerID  prev_objID prev_playerID
# 637  682.46  -5105  -1401    391  2276914         NaN           NaN
# 627  674.25  -5106  -1397    602  2276914         NaN           NaN
# 635  681.22  -5106  -1400    235  2276914         NaN           NaN
# 478  617.70  -5107  -1401   1135  2276914         NaN           NaN
# 416  585.98  -5108  -1400     31  2276914         NaN           NaN
# 456  610.03  -5108  -1400    235  2276914         0.0            -1
# 460  611.86  -5108  -1400    253  2276914       235.0       2276914
# 469  614.41  -5108  -1400     31  2276914         0.0            -1
# 497  623.25  -5108  -1400      0  2276914        31.0       2276914
# 476  617.16  -5108  -1401    253  2276914         NaN           NaN
# 482  618.45  -5108  -1401     31  2276914         0.0            -1
# 486  619.16  -5108  -1401    253  2276914         0.0            -1
# 490  619.80  -5108  -1401    253  2276914       253.0       2276914
# 495  621.44  -5108  -1401    253  2276914       253.0       2276914
# 498  623.69  -5108  -1401    253  2276914       253.0       2276914
# 500  624.92  -5108  -1401    253  2276914       253.0       2276914
# 507  626.07  -5108  -1401    253  2276914       253.0       2276914
# 519  629.64  -5108  -1401      0  2276914       253.0       2276914
# 465  613.33  -5109  -1401    391  2276914         NaN           NaN
# 492  620.65  -5109  -1401    391  2276914       391.0       2276914
# 499  624.31  -5109  -1401    391  2276914       391.0       2276914
# 505  625.48  -5109  -1401    391  2276914       391.0       2276914
# 510  626.54  -5109  -1401   1135  2276914       391.0       2276914
# 405  579.30  -5111  -1396    391  2276914         NaN           NaN
# 351  559.54  -5118  -1402      0  2276914         NaN           NaN
# 353  560.38  -5118  -1402    836  2276914         0.0       2276914
# 334  552.93  -5120  -1402   2665  2276914         NaN           NaN
# 337  554.15  -5120  -1402   2669  2276914      2665.0       2276914
# 342  555.31  -5120  -1402   2665  2276914      2669.0       2276914
# 344  556.16  -5120  -1402   2669  2276914      2665.0       2276914
# 288  538.06  -5121  -1398    198  2276914         NaN           NaN
# 247  518.01  -5122  -1393      0  2276914         NaN           NaN
# 250  519.22  -5122  -1393   3225  2276914         0.0       2276914
# 257  522.20  -5123  -1392   2742  2276914      2742.0       2276905
# 541  636.74  -5123  -1392    253  2276914         0.0       2276909
# 546  638.09  -5123  -1392    258  2276914       253.0       2276914
# 550  639.54  -5123  -1392      0  2276914       258.0       2276914
# 543  637.24  -5124  -1392   2742  2276914      2742.0       2276909
# 445  600.28  -5128  -1400   1603  2276914      1603.0       2276906

# %%
innovs_to_be_removed
# Out:
#          fam objID orig_fam
# 0    ZABICKI  2669      NaN
# 1    ZABICKI  2665      NaN
# 2    ZABICKI  2390      NaN
# 3    ZABICKI  2881      NaN
# 4    ZABICKI  2881      NaN
# 5    ZABICKI  2882      NaN
# 6    ZABICKI  2878      NaN
# 7    ZABICKI  2878      NaN
# 8    ZABICKI  3161      NaN
# 9    ZABICKI  3161      NaN
# 10   ZABICKI  3161      NaN
# 11   ZABICKI  3161      NaN
# 12   ZABICKI  3161      NaN
# 13   ZABICKI  3161      NaN
# 14   ZABICKI  3161      NaN
# 15   ZABICKI  3161      NaN
# 16   ZABICKI  3161      NaN
# 17   ZABICKI  3161      NaN
# 18   ZABICKI  3161      NaN
# 19   ZABICKI  3161      NaN
# 20   ZABICKI  3161      NaN
# 21   ZABICKI  3161      NaN
# 22   ZABICKI  3161      NaN
# 23   ZABICKI  3161      NaN
# 24   ZABICKI  3161      NaN
# 25   ZABICKI  3161      NaN
# 26   ZABICKI  3161      NaN
# 27   ZABICKI  3161      NaN
# 28   ZABICKI  3161      NaN
# 29   ZABICKI  3161      NaN
# ..       ...   ...      ...
# 460  ZABICKI   220      NaN
# 461  ZABICKI   220      NaN
# 462  ZABICKI   220      NaN
# 463  ZABICKI   220      NaN
# 464  ZABICKI    55      NaN
# 465  ZABICKI    55      NaN
# 466  ZABICKI    59      NaN
# 467  ZABICKI    59      NaN
# 468  ZABICKI    55      NaN
# 469  ZABICKI    55      NaN
# 470  ZABICKI    55      NaN
# 471  ZABICKI    55      NaN
# 472  ZABICKI    55      NaN
# 473  ZABICKI    55      NaN
# 474  ZABICKI    55      NaN
# 475  ZABICKI    55      NaN
# 476  ZABICKI    34      NaN
# 477  ZABICKI    34      NaN
# 478  ZABICKI    34      NaN
# 479  ZABICKI    34      NaN
# 480  ZABICKI    34      NaN
# 481  ZABICKI  2419      NaN
# 482  ZABICKI  2419      NaN
# 483  ZABICKI    34      NaN
# 484  ZABICKI    34      NaN
# 485  ZABICKI    31      NaN
# 486  ZABICKI    31      NaN
# 487  ZABICKI    96      NaN
# 488  ZABICKI    64      NaN
# 489  ZABICKI    31      NaN
#
# [490 rows x 3 columns]

# %%
grouped = fam_innovs.groupby(['playerID'])['objID'].count().to_frame().reset_index()
grouped.head()
# Out:
#    playerID  objID
# 0   2276905    101
# 1   2276906     19
# 2   2276909     49
# 3   2276914     55
# 4   2276922      9

# %%
innovs = data.groupby(['objID'])['playerID'].apply(lambda x: x.tolist()[0]).to_frame().reset_index()

# %%
fam_innovs.query()

# %%
innovs.head(n = 10)
# Out:
#    objID  playerID
# 0      0   2276905
# 1     30   2276906
# 2     31   2276914
# 3     32   2276908
# 4     33   2276911
# 5     34   2276908
# 6     35   2276936
# 7     39   2276911
# 8     40   2276917
# 9     45   2276908

# %% [markdown]
# ## record connection in a dataframe

# %% [markdown]
# Sort by location and time

# %%
parsed = data.sort_values(by = ['locX','locY','time']).copy()
parsed.head()
# Out:
#          time   locX   locY   obj playerID   family  objID
# 39     225.39     -3      4    87  2276907  UnKnown     87
# 5404  2264.32  -4994  -1296  3161  2276905  ZABICKI   3161
# 5407  2265.92  -4994  -1296     0  2276905  ZABICKI      0
# 5411  2267.17  -4994  -1297  3161  2276905  ZABICKI   3161
# 5414  2269.82  -4994  -1297     0  2276905  ZABICKI      0

# %% [markdown]
# tag previous player and object at this location

# %%
parsed['same_loc'] = parsed.locY.eq(parsed.locY.shift())

# %%
parsed['objID'] = parsed['obj'].apply(lambda x: int_extract('[0-9]+',x))

# %%
parsed['all_prev_obj'] = parsed.objID.shift()
parsed['prev_objID'] = parsed[parsed['same_loc']==True]['all_prev_obj']
parsed['all_prev_playerID'] = parsed.playerID.shift()
parsed['prev_playerID'] = parsed[parsed['same_loc']==True]['all_prev_playerID']

# %%
parsed = parsed[['time','locX','locY','objID','playerID','prev_objID','prev_playerID']]
parsed.head(n = 10)
# Out:
#          time   locX   locY  objID playerID  prev_objID prev_playerID
# 39     225.39     -3      4     87  2276907         NaN           NaN
# 5404  2264.32  -4994  -1296   3161  2276905         NaN           NaN
# 5407  2265.92  -4994  -1296      0  2276905      3161.0       2276905
# 5411  2267.17  -4994  -1297   3161  2276905         NaN           NaN
# 5414  2269.82  -4994  -1297      0  2276905      3161.0       2276905
# 5457  2281.49  -5006  -1322   3161  2276905         NaN           NaN
# 5469  2283.87  -5006  -1322      0  2276905      3161.0       2276905
# 5484  2286.76  -5015  -1329    647  2276905         NaN           NaN
# 5680  2316.60  -5019  -1359    382  2276905         NaN           NaN
# 5661  2313.00  -5020  -1359      0       -1       382.0       2276905

# %% [markdown]
# take data where an object at a location was changed by a different player

# %%
parsednew = parsed.loc[(parsed.obj != parsed.prev_obj) & (parsed.prev_obj != "0") \
                       & (parsed.prev_playerID != -1) & (parsed.playerID != -1)]
parsednew = parsednew.sort_values(by = ['time'])

# %%
parsednew.head(n = 10)
# Out:
#       time   locX   locY  obj  objID playerID prev_obj prev_playerID  \
# 7   122.31  -5137  -1395    0      0  2276905      NaN           NaN
# 8   125.06  -5138  -1394    0      0  2276905      NaN           NaN
# 11  129.09  -5135  -1396  134    134  2276905      NaN           NaN
# 12  130.33  -5136  -1395    0      0  2276905      NaN           NaN
# 14  145.79  -7577   -352    0      0  2276908      NaN           NaN
# 15  147.25  -5136  -1386    0      0  2276905      NaN           NaN
# 16  149.37  -5138  -1386    0      0  2276905      NaN           NaN
# 17  149.88  -7577   -349   32     32  2276908      NaN           NaN
# 18  151.23  -5137  -1386    0      0  2276905      NaN           NaN
# 19  152.21  -7581   -351  150    150  2276908      NaN           NaN
#
#    later_obj later_playerID
# 7        NaN            NaN
# 8        NaN            NaN
# 11       NaN            NaN
# 12       NaN            NaN
# 14       NaN            NaN
# 15       NaN            NaN
# 16       NaN            NaN
# 17       NaN            NaN
# 18       NaN            NaN
# 19       NaN            NaN

# %%
def extract_objID(obj):
    try:
        objid = int_extract('[0-9]+',obj)
        return objid
    except:
        return np.nan

# %%
parsednew['prev_objID'] = parsednew['prev_obj'].apply(extract_objID)
parsednew['same_obj'] = parsednew.objID.eq(parsednew.prev_objID)
# parsednew = parsednew[['time','locX','locY','obj','playerID','prev_obj','prev_playerID','same_obj']]
parsednew.head(n=20)
# Out:
#       time   locX   locY     obj  objID playerID prev_obj prev_playerID  \
# 7   122.31  -5137  -1395       0      0  2276905      NaN           NaN
# 8   125.06  -5138  -1394       0      0  2276905      NaN           NaN
# 11  129.09  -5135  -1396     134    134  2276905      NaN           NaN
# 12  130.33  -5136  -1395       0      0  2276905      NaN           NaN
# 14  145.79  -7577   -352       0      0  2276908      NaN           NaN
# 15  147.25  -5136  -1386       0      0  2276905      NaN           NaN
# 16  149.37  -5138  -1386       0      0  2276905      NaN           NaN
# 17  149.88  -7577   -349      32     32  2276908      NaN           NaN
# 18  151.23  -5137  -1386       0      0  2276905      NaN           NaN
# 19  152.21  -7581   -351     150    150  2276908      NaN           NaN
# 20  169.34  -7565   -337     224    224  2276908      NaN           NaN
# 21  171.74  -7570   -335     224    224  2276908      NaN           NaN
# 22  172.11  -5125  -1393  2873u3   2873  2276905      NaN           NaN
# 23  173.59  -7566   -336      34     34  2276908      NaN           NaN
# 24  175.11  -5123  -1392  2742u3   2742  2276905      NaN           NaN
# 25  176.76  -5122  -1392       0      0  2276905      NaN           NaN
# 27  178.88  -5125  -1393  2873u2   2873  2276905   2873u3       2276905
# 30  182.68  -5121  -1392    2861   2861  2276905      NaN           NaN
# 31  183.38  -5122  -1392       0      0  2276905     2874       2276905
# 32  186.68  -7557   -359      45     45  2276908      NaN           NaN
#
#    later_obj later_playerID  prev_objID  same_obj
# 7        NaN            NaN         NaN     False
# 8        NaN            NaN         NaN     False
# 11       NaN            NaN         NaN     False
# 12       NaN            NaN         NaN     False
# 14       NaN            NaN         NaN     False
# 15       NaN            NaN         NaN     False
# 16       NaN            NaN         NaN     False
# 17       NaN            NaN         NaN     False
# 18       NaN            NaN         NaN     False
# 19       NaN            NaN         NaN     False
# 20       NaN            NaN         NaN     False
# 21       NaN            NaN         NaN     False
# 22       NaN            NaN         NaN     False
# 23       NaN            NaN         NaN     False
# 24       NaN            NaN         NaN     False
# 25       NaN            NaN         NaN     False
# 27    2873u1        2276906      2873.0      True
# 30       NaN            NaN         NaN     False
# 31       253        2276909      2874.0     False
# 32       NaN            NaN         NaN     False

# %%
len(parsednew)
# Out:
# 1062897

# %%
duration = max(data.time) - min(data.time)
duration
# Out:
# 206688.01999998093

# %% [markdown]
# ### parse objects

# %% [markdown]
# how many unique objects are there?

# %%
all_objs = data['obj'].unique()
len(all_objs)
# Out:
# 3135

# %%
all_objID = []
for i in all_objs:
    if type(i) is str:
        all_objID.append(int_extract('[0-9]+',i))
all_objID = list(set(all_objID))

# %%
len(all_objID)
# Out:
# 2337

# %% [markdown]
# ## focus on innovations

# %% [markdown]
# create an innovation df

# %%
innovations = parsednew.query('(same_obj == False) and (obj != "0")')
innovations.head()
# Out:
#       time   locX   locY  obj  objID playerID prev_obj prev_playerID  \
# 11  129.09  -5135  -1396  134    134  2276905      NaN           NaN
# 17  149.88  -7577   -349   32     32  2276908      NaN           NaN
# 19  152.21  -7581   -351  150    150  2276908      NaN           NaN
# 20  169.34  -7565   -337  224    224  2276908      NaN           NaN
# 21  171.74  -7570   -335  224    224  2276908      NaN           NaN
#
#    later_obj later_playerID  prev_objID  same_obj
# 11       NaN            NaN           0     False
# 17       NaN            NaN           0     False
# 19       NaN            NaN           0     False
# 20       NaN            NaN           0     False
# 21       NaN            NaN           0     False

# %% [markdown]
# filter out strange objects FOR NOW

# %%
normal_objs = [i for i in all_objID if i<4000]
len(normal_objs)
# Out:
# 1754

# %%
innovations = innovations.query('(objID in @normal_objs) and (prev_objID in @normal_objs)')
len(innovations)
# Out:
# 133381

# %% [markdown]
# make sure the new object has a greater depth than the previous one

# %%
innovations['obj_depth'] = innovations['objID'].apply(find_depth)
innovations['prev_obj_depth'] = innovations['prev_objID'].apply(find_depth)
innovations['deeper'] = innovations.obj_depth>innovations.prev_obj_depth
innovations = innovations.query('deeper == True')
innovations.head()
# Out:
#       time   locX   locY     obj  objID playerID prev_obj prev_playerID  \
# 11  129.09  -5135  -1396     134    134  2276905      NaN           NaN
# 19  152.21  -7581   -351     150    150  2276908      NaN           NaN
# 20  169.34  -7565   -337     224    224  2276908      NaN           NaN
# 21  171.74  -7570   -335     224    224  2276908      NaN           NaN
# 22  172.11  -5125  -1393  2873u3   2873  2276905      NaN           NaN
#
#    later_obj later_playerID  prev_objID  same_obj  obj_depth  prev_obj_depth  \
# 11       NaN            NaN           0     False          6               0
# 19       NaN            NaN           0     False          4               0
# 20       NaN            NaN           0     False          4               0
# 21       NaN            NaN           0     False          4               0
# 22       NaN            NaN           0     False        189               0
#
#     deeper
# 11    True
# 19    True
# 20    True
# 21    True
# 22    True

# %%
len(innovations)
# Out:
# 133381

# %% [markdown]
# ## Scratch: trying to get full information regarding what the player has in hand

# %% [markdown]
# load transition data

# %%
trans_df = pd.read_csv('../3_technology/tech_outputs/transition.csv', index_col = [0])
trans_df = trans_df.replace({4348:-1, 4349:-2}).reset_index(drop = True)
trans_df.head()
# Out:
#    origActor  origTarget  newActor  newTarget
# 0         -1        2574       0.0     2578.0
# 1          0         702     425.0      695.0
# 2        314         235       0.0      317.0
# 3       2165        2165     235.0     3699.0
# 4          0        1692    1719.0     1706.0

# %%
l = adj_df[['ingredient1','ingredient2']].values
len(l)
# Out:
# 3258

# %%
kept = []
for i,j in trans_df.iterrows():
    if list(set([j['origActor'], j['origTarget']])) in l:
        kept.append(i)

# %%
adj_newdf = trans_df.iloc[kept]
adj_newdf.head()
# Out:
#    origActor  origTarget  newActor  newTarget
# 0         -1        2574       0.0     2578.0
# 2        314         235       0.0      317.0
# 3       2165        2165     235.0     3699.0
# 6         -1        2206       0.0     2208.0
# 7        455         504       0.0      811.0

# %%
len(adj_newdf)
# Out:
# 5571

# %% [markdown]
# ### test: look at an individual player

# %%
player_data = parsed.query('playerID == 2276929').sort_values(by = 'time').reset_index(drop = True)
player_data
# Out:
#        time   locX   locY     obj playerID prev_obj prev_playerID
# 0   1351.99  -5133  -1403       0  2276929      183       2276914
# 1   1354.44  -5131  -1402     183  2276929      NaN           NaN
# 2   1359.60  -5131  -1402       0  2276929      183       2276929
# 3   1359.98  -5131  -1402     183  2276929        0       2276929
# 4   1360.41  -5131  -1402       0  2276929      183       2276929
# 5   1360.77  -5131  -1402     183  2276929        0       2276929
# 6   1366.58  -5131  -1402       0  2276929      183       2276929
# 7   1368.66  -5129  -1401     183  2276929        0            -1
# 8   1369.17  -5131  -1401     255  2276929        0       2276922
# 9   1375.00  -5129  -1401       0  2276929      183       2276929
# 10  1393.17  -5125  -1401     183  2276929        0       2276905
# 11  1406.17  -5124  -1399  1471u3  2276929      NaN           NaN
# 12  1414.40  -5131  -1404       0  2276929      183       2276914
# 13  1418.51  -5131  -1407     183  2276929      NaN           NaN
# 14  1428.49  -5131  -1407       0  2276929      200       2276914
# 15  1429.97  -5131  -1407     128  2276929        0       2276929
# 16  1432.22  -5131  -1407       0  2276929      128       2276929
# 17  1432.95  -5130  -1407     128  2276929        0       2276914
# 18  1452.15  -5124  -1403       0  2276929      NaN           NaN
# 19  1453.62  -5124  -1403    1474  2276929        0       2276929
# 20  1455.50  -5121  -1402  2873u4  2276929      NaN           NaN
# 21  1543.99  -5111  -1397   391u3  2276929      NaN           NaN
# 22  1546.01  -5111  -1397   391u2  2276929    391u3       2276929
# 23  1567.44  -5129  -1392       0  2276929      198       2276906
# 24  1583.53  -5117  -1402  1471u1  2276929   1471u2       2276914
# 25  1740.31  -5115  -1405      87  2276929        0       2276909

# %%
actors = []
for i,j in player_data.iterrows():
    
    obj = int_extract('[0-9]+', j['obj'])
    prev_obj = j['prev_obj']
    possible_actors = adj_newdf.query('newTarget == @obj')['origActor'].values
    possible_actors = [i for i in possible_actors if i>=0]
    
    if (obj == 0):
        actors = np.append(actors, prev_obj)
        
    elif (prev_obj == "0"):
        actors = np.append(actors, obj)
        
    elif (len(possible_actors)>0):
#         actors_from_prev = adj_newdf.query('product == @prev_obj')['origActor']
#         actor = [i for i in possible_actors if i in actors_from_prev]
        actor = possible_actors[np.argmin([find_depth(i) for i in possible_actors])]
        if find_depth(actor)>0:
            actors = np.append(actors, actor)
        else:
            actors = np.append(actors, 0)
            
    else:
        actors = np.append(actors, 0)

# %%
player_data['hold'] = actors
player_data
# Out:
#        time   locX   locY     obj playerID prev_obj prev_playerID  hold
# 0   1351.99  -5133  -1403       0  2276929      183       2276914   183
# 1   1354.44  -5131  -1402     183  2276929      NaN           NaN     0
# 2   1359.60  -5131  -1402       0  2276929      183       2276929   183
# 3   1359.98  -5131  -1402     183  2276929        0       2276929   183
# 4   1360.41  -5131  -1402       0  2276929      183       2276929   183
# 5   1360.77  -5131  -1402     183  2276929        0       2276929   183
# 6   1366.58  -5131  -1402       0  2276929      183       2276929   183
# 7   1368.66  -5129  -1401     183  2276929        0            -1   183
# 8   1369.17  -5131  -1401     255  2276929        0       2276922   255
# 9   1375.00  -5129  -1401       0  2276929      183       2276929   183
# 10  1393.17  -5125  -1401     183  2276929        0       2276905   183
# 11  1406.17  -5124  -1399  1471u3  2276929      NaN           NaN   560
# 12  1414.40  -5131  -1404       0  2276929      183       2276914   183
# 13  1418.51  -5131  -1407     183  2276929      NaN           NaN     0
# 14  1428.49  -5131  -1407       0  2276929      200       2276914   200
# 15  1429.97  -5131  -1407     128  2276929        0       2276929   128
# 16  1432.22  -5131  -1407       0  2276929      128       2276929   128
# 17  1432.95  -5130  -1407     128  2276929        0       2276914   128
# 18  1452.15  -5124  -1403       0  2276929      NaN           NaN   nan
# 19  1453.62  -5124  -1403    1474  2276929        0       2276929  1474
# 20  1455.50  -5121  -1402  2873u4  2276929      NaN           NaN  2874
# 21  1543.99  -5111  -1397   391u3  2276929      NaN           NaN     0
# 22  1546.01  -5111  -1397   391u2  2276929    391u3       2276929     0
# 23  1567.44  -5129  -1392       0  2276929      198       2276906   198
# 24  1583.53  -5117  -1402  1471u1  2276929   1471u2       2276914   560
# 25  1740.31  -5115  -1405      87  2276929        0       2276909    87

# %%
player_data.query('(obj == "2575")')
# Out:
# Empty DataFrame
# Columns: [time, locX, locY, obj, playerID, prev_obj, prev_playerID, hold]
# Index: []

# %%
parsed.query('(locX == "-5123") and (locY == "-1412")')
# Out:
#          time   locX   locY   obj playerID prev_obj prev_playerID
# 1902  1201.01  -5123  -1412  2575  2276905      NaN           NaN

# %%
adj_newdf.query('origActor == 3052')
# Out:
# Empty DataFrame
# Columns: [origActor, origTarget, product]
# Index: []

# %%
depth.query('id == 255')
# Out:
#       id                   name  num_ingredients
# 193  255  Bowl of Minced Rabbit               70

# %% [markdown]
# ## back to innovations

# %% [markdown]
# make sure the innovation is used by a differnt player (avoid intermediate products being counted)

# %%
useful_innovations = innovations.loc[innovations.later_playerID != innovations.playerID].copy()
useful_innovations = useful_innovations[['time','locX','locY','obj','playerID','prev_obj',\
                                         'prev_playerID','later_obj','later_playerID','objID','obj_depth']]
useful_innovations.head(n=10)
# Out:
#       time   locX   locY     obj playerID prev_obj prev_playerID later_obj  \
# 11  129.09  -5135  -1396     134  2276905      NaN           NaN       NaN
# 19  152.21  -7581   -351     150  2276908      NaN           NaN       NaN
# 20  169.34  -7565   -337     224  2276908      NaN           NaN       NaN
# 21  171.74  -7570   -335     224  2276908      NaN           NaN       NaN
# 22  172.11  -5125  -1393  2873u3  2276905      NaN           NaN       NaN
# 23  173.59  -7566   -336      34  2276908      NaN           NaN       NaN
# 24  175.11  -5123  -1392  2742u3  2276905      NaN           NaN       NaN
# 30  182.68  -5121  -1392    2861  2276905      NaN           NaN       NaN
# 32  186.68  -7557   -359      45  2276908      NaN           NaN       NaN
# 34  201.17  -7569   -335      66  2276908      NaN           NaN       NaN
#
#    later_playerID  objID  obj_depth
# 11            NaN    134          6
# 19            NaN    150          4
# 20            NaN    224          4
# 21            NaN    224          4
# 22            NaN   2873        189
# 23            NaN     34          2
# 24            NaN   2742         55
# 30            NaN   2861        174
# 32            NaN     45          1
# 34            NaN     66          1

# %%
len(useful_innovations)
# Out:
# 133381

# %%
def find_num(objs):
    try:
        return len(set(objs))
    except:
        return 0

# %% [markdown]
# count the number of innovations per player (defined as depth(present_obj) > depth(previous_obj))

# %%
creator_df = useful_innovations.groupby(['playerID'])['objID'].apply(list).to_frame().reset_index()
creator_df['innovations'] = creator_df['objID'].apply(lambda x: len(set(x)))
creator_df = creator_df.sort_values(by = 'innovations', ascending = False)
creator_df['playerID'] = creator_df['playerID'].astype(int)
creator_df.head()
# Out:
#       playerID                                              objID  innovations
# 1414   2279373  [48, 64, 64, 2882, 345, 1317, 593, 72, 72, 72,...           87
# 1209   2279012  [391, 1217, 1217, 2742, 1217, 1217, 1108, 3179...           71
# 1550   2279579  [123, 123, 123, 34, 292, 141, 292, 141, 150, 2...           62
# 1927   2281733  [1262, 395, 395, 141, 1262, 141, 141, 1262, 14...           60
# 3499   2284428  [55, 57, 220, 57, 55, 58, 58, 54, 57, 55, 59, ...           60

# %%
first_loc = parsed.loc[(parsed.prev_playerID.isnull()) & (parsed.playerID != -1) & (parsed.obj != "0")].copy()
first_loc.head()
# Out:
#               time    locX   locY   obj  objID playerID prev_obj  \
# 952037    49726.09  -10000  -1042  2144   2144  2279625      NaN
# 1049318   91043.70  -10000  -1101    32     32  2281593      NaN
# 2258681  159274.73  -10000   -220    34     34  2285145      NaN
# 2251001  158631.87  -10000   -221   167    167  2285080      NaN
# 2289688  161759.75  -10000   -255    64     64  2285145      NaN
#
#         prev_playerID later_obj later_playerID
# 952037            NaN       NaN            NaN
# 1049318           NaN       NaN            NaN
# 2258681           NaN       NaN            NaN
# 2251001           NaN       NaN            NaN
# 2289688           NaN       NaN            NaN

# %%
len(first_loc.playerID.unique())
# Out:
# 5049

# %%
# first_loc = first_loc.sort_values(by = 'playerID')
first_loc_objs = first_loc.groupby('playerID')['objID'].apply(list).to_frame().reset_index()
first_loc_objs.head()
# Out:
#    playerID                                              objID
# 0   2276905  [3161, 3161, 3161, 647, 382, 1603, 2140, 3161,...
# 1   2276906  [87, 2919, 2146, 242, 223, 1160, 1242, 30, 396...
# 2   2276907                                               [87]
# 3   2276908      [87, 45, 224, 34, 225, 225, 66, 224, 32, 150]
# 4   2276909  [64, 66, 45, 48, 614, 614, 224, 224, 602, 45, ...

# %%
player_prev_obj = parsed.groupby('playerID')['prev_obj'].apply(list).to_frame().reset_index()
player_prev_obj.head()
# Out:
#    playerID                                           prev_obj
# 0        -1  [nan, nan, 807, nan, nan, nan, nan, 57, 344, n...
# 1   2276905  [nan, 3161, nan, 3161, nan, 3161, nan, nan, 0,...
# 2   2276906  [nan, nan, nan, nan, nan, nan, nan, 0, nan, 0,...
# 3   2276907                                              [nan]
# 4   2276908  [nan, nan, nan, 224, nan, nan, nan, nan, nan, ...

# %%
merged_loc = pd.merge(first_loc_objs, player_prev_obj, on = 'playerID', how = 'left')
merged_loc.head()
# Out:
#    playerID                                              objID  \
# 0   2276905  [3161, 3161, 3161, 647, 382, 1603, 2140, 3161,...
# 1   2276906  [87, 2919, 2146, 242, 223, 1160, 1242, 30, 396...
# 2   2276907                                               [87]
# 3   2276908      [87, 45, 224, 34, 225, 225, 66, 224, 32, 150]
# 4   2276909  [64, 66, 45, 48, 614, 614, 224, 224, 602, 45, ...
#
#                                             prev_obj
# 0  [nan, 3161, nan, 3161, nan, 3161, nan, nan, 0,...
# 1  [nan, nan, nan, nan, nan, nan, nan, 0, nan, 0,...
# 2                                              [nan]
# 3  [nan, nan, nan, 224, nan, nan, nan, nan, nan, ...
# 4  [nan, 64, nan, nan, nan, nan, nan, 0, nan, nan...

# %%
creator_newdf = creator_df.copy()
for i,j in merged_loc.iterrows():
    obj_list = j['objID']
    player = j['playerID']
    prev_list = j['prev_obj']
    objs = [i for i in obj_list if i not in prev_list]
    if player in creator_newdf.playerID.values:
        old_list = creator_newdf.loc[creator_newdf.playerID == player]['objID'].values[0]
        entry = pd.Series([objs + old_list], index = creator_newdf.loc[creator_newdf.playerID == player].index, dtype = 'object')
        creator_newdf.loc[creator_newdf.playerID == player, 'newobjID'] = entry         
    else: 
        creator_newdf = creator_newdf.append({'playerID':player, 'newobjID':objs}, ignore_index=True)

# %%
creator_newdf['num_innovations'] = creator_newdf['newobjID'].apply(find_num)

# %%
creator_newdf = creator_newdf[['playerID','newobjID','num_innovations']].sort_values(by='num_innovations', ascending=False)

# %%
creator_newdf.head()
# Out:
#    playerID                                           newobjID  \
# 0   2279373  [3161, 2144, 812, 812, 812, 48, 3161, 593, 812...
# 1   2279012  [1247, 1247, 135, 1113, 292, 334, 1108, 1146, ...
# 3   2281733  [1157, 471, 1114, 126, 190, 190, 135, 190, 190...
# 8   2276905  [3161, 3161, 3161, 647, 382, 1603, 2140, 3161,...
# 2   2279579  [3161, 3161, 3161, 33, 107, 292, 3161, 292, 31...
#
#    num_innovations
# 0               93
# 1               75
# 3               67
# 8               66
# 2               66

# %%
innovation_expertise_merged = pd.merge(creator_newdf, expertise[['playerID','age','gametime']], on= 'playerID')
innovation_expertise_merged.head(n=20)
# Out:
#     playerID                                           newobjID  \
# 0    2279373  [3161, 2144, 812, 812, 812, 48, 3161, 593, 812...
# 1    2279012  [1247, 1247, 135, 1113, 292, 334, 1108, 1146, ...
# 2    2281733  [1157, 471, 1114, 126, 190, 190, 135, 190, 190...
# 3    2276905  [3161, 3161, 3161, 647, 382, 1603, 2140, 3161,...
# 4    2279579  [3161, 3161, 3161, 33, 107, 292, 3161, 292, 31...
# 5    2278592  [34, 39, 292, 33, 2419, 53, 57, 292, 53, 45, 6...
# 6    2285148  [30, 57, 54, 54, 54, 30, 58, 53, 57, 55, 54, 5...
# 7    2279230  [1422, 1422, 1422, 42731087, 1422, 1422, 2881,...
# 8    2284428  [2144, 2144, 152, 806, 152, 34, 3146, 2835, 34...
# 9    2276927  [198, 3051, 1376, 1314, 225, 225, 225, 225, 22...
# 10   2279293  [198, 1126, 564, 2836, 674, 248, 135, 292, 159...
# 11   2277183  [138, 484, 66, 64, 45, 48, 484, 344, 163, 292,...
# 12   2283053  [99, 404, 34, 34, 224, 32, 34, 34, 34, 34, 404...
# 13   2282067  [30, 1598, 290, 87, 1598, 292, 55, 57, 292, 29...
# 14   2283042  [715, 31, 99, 198, 96, 96, 34, 99, 34, 1315, 1...
# 15   2283352  [30, 292, 53, 48, 57, 30, 808, 292, 245, 45, 5...
# 16   2286004  [30, 292, 292, 48, 292, 30, 292, 409, 806, 806...
# 17   2278627  [876, 198, 585, 128, 2920, 198, 2886, 148, 560...
# 18   2284397  [1099, 1134, 1134, 1134, 1134, 391, 1099, 2144...
# 19   2277316  [806, 224, 34, 2302, 1126, 660, 236, 225, 411,...
#
#     num_innovations    age   gametime
# 0                93  60.00    8190.79
# 1                75  60.00    3753.54
# 2                67  60.00   26092.11
# 3                66  60.00    9928.12
# 4                66  60.00  134739.56
# 5                65  52.79   43105.78
# 6                65  59.63   18576.35
# 7                65  60.00    8125.17
# 8                65  60.00   15738.93
# 9                63  60.00   33202.20
# 10               63  58.95    7679.04
# 11               62  60.00    2317.99
# 12               62  60.00   13655.00
# 13               62  50.19    7240.38
# 14               61  55.04    2349.70
# 15               61  60.00   18818.44
# 16               61  60.00   14532.00
# 17               61  60.00    2063.03
# 18               60  60.00   14398.12
# 19               59  60.00   43696.43

# %%
innovation_expertise_merged[['playerID','num_innovations','age','gametime']].to_csv('innovations_v2.csv')
