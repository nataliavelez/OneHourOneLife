# %%
import os, sys

# _, obj_str = sys.argv
obj_str = '3644'
obj_no = int(obj_str)

obj_dir = '../../OneLifeData7/objects'
os.listdir(obj_dir)
# Out:
# ['3644.txt',
#  '1053.txt',
#  '1735.txt',
#  '3122.txt',
#  '2228.txt',
#  '3136.txt',
#  '1721.txt',
#  '1047.txt',
#  '3650.txt',
#  '3678.txt',
#  '2566.txt',
#  '2200.txt',
#  '1709.txt',
#  '289.txt',
#  '2214.txt',
#  '2572.txt',
#  '504.txt',
#  '1090.txt',
#  '2599.txt',
#  '3687.txt',
#  '262.txt',
#  '276.txt',
#  '3693.txt',
#  '1084.txt',
#  '510.txt',
#  '3863.txt',
#  '538.txt',
#  '1912.txt',
#  '1906.txt',
#  '3877.txt',
#  '1251.txt',
#  '2758.txt',
#  '3446.txt',
#  '3452.txt',
#  '2994.txt',
#  '1245.txt',
#  '3334.txt',
#  '2002.txt',
#  '921.txt',
#  '935.txt',
#  '1279.txt',
#  '2770.txt',
#  '3308.txt',
#  '2016.txt',
#  '3485.txt',
#  '2943.txt',
#  '1292.txt',
#  '706.txt',
#  '712.txt',
#  '1286.txt',
#  '2957.txt',
#  '3254.txt',
#  '1443.txt',
#  '1325.txt',
#  '869.txt',
#  '3532.txt',
#  '3526.txt',
#  '2638.txt',
#  '1331.txt',
#  '3240.txt',
#  '2176.txt',
#  '3268.txt',
#  '2610.txt',
#  '855.txt',
#  '699.txt',
#  '841.txt',
#  '2604.txt',
# ...
